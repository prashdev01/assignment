# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.set_index('Name')
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
df.set_index('Name', inplace=True)

# %%
df.reset_index()
# Out:
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                             Allen, Mr. William Henry            5         0
# ..                                                 ...          ...       ...
# 886                              Montvila, Rev. Juozas          887         0
# 887                       Graham, Miss. Margaret Edith          888         1
# 888           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 889                              Behr, Mr. Karl Howell          890         1
# 890                                Dooley, Mr. Patrick          891         0
#
# ...

# %%
df1 = df

# %%
df1.dropna(axis=1)
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
df1.reset_index(inplace=True)

# %%
df1.dropna()
# Out:
#                                                   Name  PassengerId  Survived  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 6                              McCarthy, Mr. Timothy J            7         0
# 10                     Sandstrom, Miss. Marguerite Rut           11         1
# 11                            Bonnell, Miss. Elizabeth           12         1
# ..                                                 ...          ...       ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)          872         1
# 872                           Carlsson, Mr. Frans Olof          873         0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)          880         1
# 887                       Graham, Miss. Margaret Edith          888         1
# 889                              Behr, Mr. Karl Howell          890         1
#
# ...

# %%
df1.fillna("empty")
# Out:
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                             Allen, Mr. William Henry            5         0
# ..                                                 ...          ...       ...
# 886                              Montvila, Rev. Juozas          887         0
# 887                       Graham, Miss. Margaret Edith          888         1
# 888           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 889                              Behr, Mr. Karl Howell          890         1
# 890                                Dooley, Mr. Patrick          891         0
#
# ...

# %%
g = df1.groupby((['Age' , 'Fare' ]))

# %%
g.sum().T
# Out:
# C:\Users\SHIV\AppData\Local\Temp\ipykernel_9580\580977572.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.sum().T
# Age            0.42     0.67     0.75     0.83              0.92     1.00   \
# Fare        8.5167   14.5000  19.2583  18.7500  29.0000  151.5500 11.1333
# PassengerId      804      756     1115      832       79      306      173
# Survived           1        1        2        1        1        1        1
# Pclass             3        2        6        2        2        1        3
# SibSp              0        1        4        1        0        1        1
# Parch              1        1        2        1        2        2        1
#
# Age                                     ...    65.00             66.00  \
# ...

# %%
df5 = df[['Name', 'Survived' , 'Pclass']][5:10]
df6 = df[['Name', 'Survived' , 'Pclass']][0:5]

# %%
df5
# Out:
#                                                 Name  Survived  Pclass
# 5                                   Moran, Mr. James         0       3
# 6                            McCarthy, Mr. Timothy J         0       1
# 7                     Palsson, Master. Gosta Leonard         0       3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 9                Nasser, Mrs. Nicholas (Adele Achem)         1       2

# %%
pd.concat([df5,df6])
# Out:
#                                                 Name  Survived  Pclass
# 5                                   Moran, Mr. James         0       3
# 6                            McCarthy, Mr. Timothy J         0       1
# 7                     Palsson, Master. Gosta Leonard         0       3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 9                Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                           Allen, Mr. William Henry         0       3

# %%
pd.concat([df5,df6] ,axis=1)
# Out:
#                                                 Name  Survived  Pclass  \
# 5                                   Moran, Mr. James       0.0     3.0
# 6                            McCarthy, Mr. Timothy J       0.0     1.0
# 7                     Palsson, Master. Gosta Leonard       0.0     3.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       1.0     3.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)       1.0     2.0
# 0                                                NaN       NaN     NaN
# 1                                                NaN       NaN     NaN
# 2                                                NaN       NaN     NaN
# 3                                                NaN       NaN     NaN
# 4                                                NaN       NaN     NaN
#
#                                                 Name  Survived  Pclass
# 5                                                NaN       NaN     NaN
# ...

# %%
# merger opreation import pandas as pd

# create a DataFrame
import pandas as pd

data1 = pd.DataFrame({'key': ['A', 'B', 'C', 'D'], 'value': [1, 2, 3, 4]})
data2 = pd.DataFrame({'key': ['B', 'D', 'E', 'F'], 'value': [5, 6, 7, 8]})

df3 = pd.DataFrame(data1)
df4 = pd.DataFrame(data2)

# %%
pd.merge(data1,data2 , how='outer')
# Out:
#   key  value
# 0   A      1
# 1   B      2
# 2   C      3
# 3   D      4
# 4   B      5
# 5   D      6
# 6   E      7
# 7   F      8

# %%
import pandas as pd

df11 = pd.DataFrame({'id': [1, 2, 3], 'name': ['Alice', 'Bob', 'Charlie']})
df22 = pd.DataFrame({'id': [2, 3, 4], 'age': [25, 30, 35]})

# %%
df11.join(df22.set_index('id') ,on='id')
# Out:
#    id     name   age
# 0   1    Alice   NaN
# 1   2      Bob  25.0
# 2   3  Charlie  30.0

# %%
# apply function
df['Fare_inr'] = df['Fare'].apply(lambda x:x*80)

# %%
df
# Out:
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                             Allen, Mr. William Henry            5         0
# ..                                                 ...          ...       ...
# 886                              Montvila, Rev. Juozas          887         0
# 887                       Graham, Miss. Margaret Edith          888         1
# 888           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 889                              Behr, Mr. Karl Howell          890         1
# 890                                Dooley, Mr. Patrick          891         0
#
# ...

# %%
df = df.drop('Fare_inner' ,axis=1 )

# %%
df
# Out:
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                             Allen, Mr. William Henry            5         0
# ..                                                 ...          ...       ...
# 886                              Montvila, Rev. Juozas          887         0
# 887                       Graham, Miss. Margaret Edith          888         1
# 888           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 889                              Behr, Mr. Karl Howell          890         1
# 890                                Dooley, Mr. Patrick          891         0
#
# ...

# %%
df['len_name'] = df['Name'].apply(len)

# %%
df
# Out:
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                             Allen, Mr. William Henry            5         0
# ..                                                 ...          ...       ...
# 886                              Montvila, Rev. Juozas          887         0
# 887                       Graham, Miss. Margaret Edith          888         1
# 888           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 889                              Behr, Mr. Karl Howell          890         1
# 890                                Dooley, Mr. Patrick          891         0
#
# ...

# %%
def cal_fare(x):
    if x <10:
        return 'cheap'
    elif x>=10 and x<20:
        return 'mid'
    else :
        return 'high'

# %%
df['cal_Fare'] = df['Fare'].apply(cal_fare)

# %%
df
# Out:
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                             Allen, Mr. William Henry            5         0
# ..                                                 ...          ...       ...
# 886                              Montvila, Rev. Juozas          887         0
# 887                       Graham, Miss. Margaret Edith          888         1
# 888           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 889                              Behr, Mr. Karl Howell          890         1
# 890                                Dooley, Mr. Patrick          891         0
#
# ...
