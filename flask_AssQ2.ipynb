# %% [markdown]
# # Q1. Explain GET and POST methods.
# ### GET method is used to pass the data through URL
# ### POST method is used to pass the data through body

# %% [markdown]
# # Q2. Why is request used in Flask?
#
# ## request in flask is used to access incoming data

# %% [markdown]
# # Q3. Why is redirect() used in Flask?
#
# ## the redirect() is used to redirect the user to a specified URL or specied status cose

# %% [markdown]
# # Q4. What are templates in Flask? Why is the render_template() function used?
# ## the templete in flask stores the static data , in our application we used render_templete() to render html on the client side

# %% [markdown]
# # Q5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.
# ![image.png](attachment:ad12a86d-c486-4b0c-a493-6dc3f5b60df5.png)

# %% [markdown]
# ![image.png](attachment:1a8526b3-b03a-4ea1-bc62-91669a365f99.png)
