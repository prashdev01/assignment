# %% [markdown]
# # Q1. What is Flask Framework? What are the advantages of Flask Framework?
# ## flask is python library for web development
# ## flask is lightweight and simple to use

# %% [markdown]
#  # Q2. Create a simple Flask application to display ‘Hello World!!’.

# %% [markdown]
# ![image.png](attachment:a9bdbf34-e065-4112-b208-6b2ddb51b9b5.png)

# %% [markdown]
# ![image.png](attachment:315258a8-2321-4b41-bcec-9609bcf60e4f.png)

# %% [markdown]
# # Q3. What is App routing in Flask? Why do we use app routes?
# ### it is process of mapping URL to function in a flask application
# ### app route is bind an URL to function , that means when we hit specifed URL which is binded with the function we are executing the function

# %% [markdown]
# # Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# ## route to show the following details:
# ### Company Name: ABC Corporation
# ### Location: India
# ### Contact Detail: 999-999-9999

# %% [markdown]
# ![image.png](attachment:49168feb-f603-4e1a-8f0c-abed6d5abd52.png)

# %% [markdown]
# ![image.png](attachment:f7dbb74e-24cb-4052-bc40-b41bb1877088.png)

# %% [markdown]
# ![image.png](attachment:30fb807c-22e7-4dc9-b822-2c52fa2eaeb4.png)

# %% [markdown]
# # Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %% [markdown]
# ### the function used for URL building in flask is url_for()

# %%
from flask import Flask, url_for
from flask import Flask

app = Flask(__name__)

@app.route('/')
def index():
    return 'index'

@app.route('/login')
def login():
    return 'login'

@app.route('/user/<username>')
def profile(username):
    return f'{username}\'s profile'

with app.test_request_context():
    print(url_for('index'))
    print(url_for('login'))
    print(url_for('login', next='/'))
    print(url_for('profile', username='John Doe'))

if __name__ == "__main__":
    app.run(host='0.0.0.0')
